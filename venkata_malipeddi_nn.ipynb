# %% [markdown]
# Problem statement: To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %% [markdown]
# ### Importing Skin Cancer Data
# #### To do: Take necessary actions to read the data

# %% [markdown]
# ### Importing all the important libraries

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
## If you are using the data by mounting the google drive, use the following :
from google.colab import drive
drive.mount('/content/gdrive')

##Ref:https://towardsdatascience.com/downloading-datasets-into-google-drive-via-google-colab-bcb1b30b0166
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# This assignment uses a dataset of about 2357 images of skin cancer types. The dataset contains 9 sub-directories in each train and test subdirectories. The 9 sub-directories contains the images of 9 skin cancer types respectively.

# %%
# Defining the path for train and test images
## Todo: Update the paths of the train and test dataset
data_dir_train = pathlib.Path("/content/gdrive/MyDrive/CNN_Assignment/Skin/Train")
data_dir_test = pathlib.Path('/content/gdrive/MyDrive/CNN_Assignment/Skin/Test')

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %% [markdown]
# ### Load using keras.preprocessing
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.

# %% [markdown]
# ### Create a dataset
#
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
## Write your train dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    seed=123,
    validation_split= 0.2,
    subset= 'training',
    image_size=(img_height,img_width),
    batch_size = batch_size
)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.

# %%
## Write your validation dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    seed=123,
    validation_split= 0.2,
    subset= 'validation',
    image_size=(img_height,img_width),
    batch_size = batch_size
)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.

# %%
# For Test 

test_ds = tf.keras.preprocessing.image_dataset_from_directory(data_dir_test,
                                                             seed=123,
                                                             image_size=(img_height,img_width),
                                                             batch_size=batch_size,
                                                             color_mode='rgb')
# Out:
# Found 118 files belonging to 9 classes.

# %%
# List out all the classes of skin cancer and store them in a list. 
# You can find the class names in the class_names attribute on these datasets. 
# These correspond to the directory names in alphabetical order.
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# ### Visualize the data
# #### Todo, create a code to visualize one instance of all the nine classes present in the dataset

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,10))
for i in range(9): 
  plt.subplot(3, 3, i + 1)
  image = plt.imread(str(list(data_dir_train.glob(class_names[i]+'/*.jpg'))[1]))
  plt.title(class_names[i])
  plt.imshow(image)

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
test_ds = test_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Create the model
# #### Todo: Create a CNN model, which can accurately detect 9 classes present in the dataset. Use ```layers.experimental.preprocessing.Rescaling``` to normalize pixel values between (0,1). The RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network. Here, it is good to standardize values to be in the `[0, 1]`

# %%
### Your code goes here
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D

# %%
num_classes = 9
model = Sequential([
                    layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width,3))
])

# first conv layer
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu', input_shape = (180, 180, 32)))
# second conv layer
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))

# third conv layer
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))

# fourth conv_layer
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))

# fifth conv_layer
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.25))

# flatten and put  a fully connected layer
model.add(Flatten())
model.add(Dense(num_classes, activation = "softmax"))

# %% [markdown]
# ### Compile the model
# Choose an appropirate optimiser and loss function for model training

# %%
### Todo, choose an appropirate optimiser and loss function
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 32)      2432
#
#  conv2d_1 (Conv2D)           (None, 180, 180, 32)      25632
#
#  max_pooling2d (MaxPooling2D  (None, 90, 90, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 90, 90, 32)        25632
#
#  max_pooling2d_1 (MaxPooling  (None, 45, 45, 32)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 45, 45, 32)        25632
#
#  max_pooling2d_2 (MaxPooling  (None, 22, 22, 32)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 22, 22, 32)        25632
#
#  max_pooling2d_3 (MaxPooling  (None, 11, 11, 32)       0
#  2D)
#
#  dropout (Dropout)           (None, 11, 11, 32)        0
#
#  flatten (Flatten)           (None, 3872)              0
#
#  dense (Dense)               (None, 9)                 34857
#
# =================================================================
# Total params: 139,817
# Trainable params: 139,817
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.10/dist-packages/keras/backend.py:5612: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 56/56 [==============================] - 340s 1s/step - loss: 2.0723 - accuracy: 0.1791 - val_loss: 2.0373 - val_accuracy: 0.1924
# Epoch 2/20
# 56/56 [==============================] - 5s 86ms/step - loss: 2.0237 - accuracy: 0.2132 - val_loss: 2.0289 - val_accuracy: 0.1924
# Epoch 3/20
# 56/56 [==============================] - 5s 87ms/step - loss: 2.0280 - accuracy: 0.1903 - val_loss: 2.0250 - val_accuracy: 0.1924
# Epoch 4/20
# 56/56 [==============================] - 5s 87ms/step - loss: 2.0182 - accuracy: 0.1981 - val_loss: 2.0084 - val_accuracy: 0.2058
# Epoch 5/20
# 56/56 [==============================] - 5s 86ms/step - loss: 1.9445 - accuracy: 0.2656 - val_loss: 1.8285 - val_accuracy: 0.3512
# Epoch 6/20
# 56/56 [==============================] - 5s 86ms/step - loss: 1.8656 - accuracy: 0.3019 - val_loss: 1.8893 - val_accuracy: 0.2796
# Epoch 7/20
# 56/56 [==============================] - 5s 86ms/step - loss: 1.7826 - accuracy: 0.3438 - val_loss: 1.7674 - val_accuracy: 0.3400
# Epoch 8/20
# 56/56 [==============================] - 5s 85ms/step - loss: 1.7091 - accuracy: 0.3650 - val_loss: 1.8027 - val_accuracy: 0.3400
# Epoch 9/20
# 56/56 [==============================] - 5s 88ms/step - loss: 1.6836 - accuracy: 0.3878 - val_loss: 1.6448 - val_accuracy: 0.3937
# Epoch 10/20
# 56/56 [==============================] - 5s 86ms/step - loss: 1.5882 - accuracy: 0.4202 - val_loss: 1.5661 - val_accuracy: 0.4787
# Epoch 11/20
# 56/56 [==============================] - 5s 86ms/step - loss: 1.5472 - accuracy: 0.4459 - val_loss: 1.5524 - val_accuracy: 0.4676
# Epoch 12/20
# 56/56 [==============================] - 5s 88ms/step - loss: 1.5198 - accuracy: 0.4609 - val_loss: 1.5533 - val_accuracy: 0.4810
# Epoch 13/20
# 56/56 [==============================] - 5s 86ms/step - loss: 1.4849 - accuracy: 0.4771 - val_loss: 1.6354 - val_accuracy: 0.4385
# Epoch 14/20
# 56/56 [==============================] - 5s 85ms/step - loss: 1.6979 - accuracy: 0.3778 - val_loss: 1.6157 - val_accuracy: 0.4295
# Epoch 15/20
# 56/56 [==============================] - 5s 86ms/step - loss: 1.5224 - accuracy: 0.4436 - val_loss: 1.5876 - val_accuracy: 0.4653
# Epoch 16/20
# 56/56 [==============================] - 5s 85ms/step - loss: 1.4323 - accuracy: 0.4838 - val_loss: 1.4882 - val_accuracy: 0.5168
# Epoch 17/20
# 56/56 [==============================] - 5s 86ms/step - loss: 1.3697 - accuracy: 0.5179 - val_loss: 1.5115 - val_accuracy: 0.5011
# Epoch 18/20
# 56/56 [==============================] - 5s 86ms/step - loss: 1.3193 - accuracy: 0.5279 - val_loss: 1.5112 - val_accuracy: 0.5369
# Epoch 19/20
# 56/56 [==============================] - 5s 85ms/step - loss: 1.3472 - accuracy: 0.5195 - val_loss: 1.4740 - val_accuracy: 0.4966
# Epoch 20/20
# 56/56 [==============================] - 5s 87ms/step - loss: 1.2667 - accuracy: 0.5586 - val_loss: 1.4242 - val_accuracy: 0.5056

# %% [markdown]
# ### Visualizing training results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit

# %% [markdown]
# ### Write your findings here
#  Training accuracy is 85% and validation accuracy is 46%, This confirms model is overfitting

# %%
# Todo, after you have analysed the model fit history for presence of underfit or overfit, choose an appropriate data augumentation strategy. 
# Your code goes here
data_aug = keras.Sequential([
                             layers.experimental.preprocessing.RandomFlip(mode="horizontal_and_vertical",input_shape=(img_height,img_width,3)),
                             layers.experimental.preprocessing.RandomRotation(0.2, fill_mode='reflect'),
                             layers.experimental.preprocessing.RandomZoom(height_factor=(0.2, 0.3), width_factor=(0.2, 0.3), fill_mode='reflect')
])

# %%
# Todo, visualize how your augmentation strategy works for one instance of training image.
# Your code goes here
plt.figure(figsize=(12, 12))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(data_aug(images)[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %% [markdown]
# ### Todo:
# ### Create the model, compile and train the model

# %%
## You can use Dropout layer if there is an evidence of overfitting in your findings

## Your code goes here
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
num_classes = 9
model = Sequential([ data_aug,
                    layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width,3))
      
])
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu', input_shape = (180, 180, 32)))
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.25))
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.25))
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.25))


model.add(Flatten())
model.add(Dense(num_classes, activation = "softmax"))

# %% [markdown]
# ### Compiling the model

# %%
## Your code goes here
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# ### Training the model

# %%
## Your code goes here, note: train your model for 20 epochs
epochs=20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 7s 93ms/step - loss: 2.0595 - accuracy: 0.1780 - val_loss: 2.0944 - val_accuracy: 0.2058
# Epoch 2/20
# 56/56 [==============================] - 5s 91ms/step - loss: 2.0281 - accuracy: 0.1875 - val_loss: 2.0339 - val_accuracy: 0.1924
# Epoch 3/20
# 56/56 [==============================] - 5s 90ms/step - loss: 2.0267 - accuracy: 0.2227 - val_loss: 1.9896 - val_accuracy: 0.2506
# Epoch 4/20
# 56/56 [==============================] - 5s 90ms/step - loss: 2.0201 - accuracy: 0.2316 - val_loss: 2.0612 - val_accuracy: 0.2036
# Epoch 5/20
# 56/56 [==============================] - 5s 90ms/step - loss: 2.0282 - accuracy: 0.2020 - val_loss: 2.0358 - val_accuracy: 0.1924
# Epoch 6/20
# 56/56 [==============================] - 5s 88ms/step - loss: 2.0208 - accuracy: 0.1987 - val_loss: 2.0294 - val_accuracy: 0.2036
# Epoch 7/20
# 56/56 [==============================] - 5s 89ms/step - loss: 2.0187 - accuracy: 0.2054 - val_loss: 2.0125 - val_accuracy: 0.2148
# Epoch 8/20
# 56/56 [==============================] - 5s 90ms/step - loss: 2.0043 - accuracy: 0.2422 - val_loss: 1.9731 - val_accuracy: 0.2819
# Epoch 9/20
# 56/56 [==============================] - 5s 89ms/step - loss: 1.9347 - accuracy: 0.2919 - val_loss: 1.9724 - val_accuracy: 0.2774
# Epoch 10/20
# 56/56 [==============================] - 5s 90ms/step - loss: 1.8822 - accuracy: 0.3008 - val_loss: 1.8056 - val_accuracy: 0.3400
# Epoch 11/20
# 56/56 [==============================] - 5s 89ms/step - loss: 1.7990 - accuracy: 0.3292 - val_loss: 1.8009 - val_accuracy: 0.2707
# Epoch 12/20
# 56/56 [==============================] - 5s 89ms/step - loss: 1.7998 - accuracy: 0.3376 - val_loss: 1.7855 - val_accuracy: 0.3468
# Epoch 13/20
# 56/56 [==============================] - 5s 90ms/step - loss: 1.7869 - accuracy: 0.3192 - val_loss: 1.8042 - val_accuracy: 0.3333
# Epoch 14/20
# 56/56 [==============================] - 5s 88ms/step - loss: 1.7600 - accuracy: 0.3393 - val_loss: 1.7548 - val_accuracy: 0.3400
# Epoch 15/20
# 56/56 [==============================] - 5s 91ms/step - loss: 1.7598 - accuracy: 0.3371 - val_loss: 1.7587 - val_accuracy: 0.3468
# Epoch 16/20
# 56/56 [==============================] - 5s 89ms/step - loss: 1.7599 - accuracy: 0.3438 - val_loss: 1.7499 - val_accuracy: 0.3400
# Epoch 17/20
# 56/56 [==============================] - 5s 89ms/step - loss: 1.7457 - accuracy: 0.3488 - val_loss: 1.7541 - val_accuracy: 0.3468
# Epoch 18/20
# 56/56 [==============================] - 5s 91ms/step - loss: 1.7278 - accuracy: 0.3493 - val_loss: 1.8204 - val_accuracy: 0.2662
# Epoch 19/20
# 56/56 [==============================] - 5s 88ms/step - loss: 1.7437 - accuracy: 0.3382 - val_loss: 1.7904 - val_accuracy: 0.2796
# Epoch 20/20
# 56/56 [==============================] - 5s 90ms/step - loss: 1.7094 - accuracy: 0.3594 - val_loss: 1.7334 - val_accuracy: 0.3602

# %% [markdown]
# ### Visualizing the results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# Data augmentation helpded reduce overfitting

# %% [markdown]
# #### **Todo:** Find the distribution of classes in the training dataset.
# #### **Context:** Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
## Your code goes here.
# Checking the distribution classes
path_list=[]
lesion_list=[]
for i in class_names:
      
    for j in data_dir_train.glob(i+'/*.jpg'):
        path_list.append(str(j))
        lesion_list.append(i)
dataframe_dict_original = dict(zip(path_list, lesion_list))
original_df = pd.DataFrame(list(dataframe_dict_original.items()),columns = ['Path','Label'])
original_df
# Out:
#                                                    Path              Label
# 0     /content/gdrive/MyDrive/CNN_Assignment/Skin/Tr...  actinic keratosis
# 1     /content/gdrive/MyDrive/CNN_Assignment/Skin/Tr...  actinic keratosis
# 2     /content/gdrive/MyDrive/CNN_Assignment/Skin/Tr...  actinic keratosis
# 3     /content/gdrive/MyDrive/CNN_Assignment/Skin/Tr...  actinic keratosis
# 4     /content/gdrive/MyDrive/CNN_Assignment/Skin/Tr...  actinic keratosis
# ...                                                 ...                ...
# 2234  /content/gdrive/MyDrive/CNN_Assignment/Skin/Tr...    vascular lesion
# 2235  /content/gdrive/MyDrive/CNN_Assignment/Skin/Tr...    vascular lesion
# 2236  /content/gdrive/MyDrive/CNN_Assignment/Skin/Tr...    vascular lesion
# 2237  /content/gdrive/MyDrive/CNN_Assignment/Skin/Tr...    vascular lesion
# 2238  /content/gdrive/MyDrive/CNN_Assignment/Skin/Tr...    vascular lesion
#
# [2239 rows x 2 columns]

# %%
count=[]
for i in class_names:
    count.append(len(list(data_dir_train.glob(i+'/*.jpg'))))
plt.figure(figsize=(25,10))
plt.bar(class_names,count)
# Out:
# <BarContainer object of 9 artists>

# %%
# Getting the count
for i in range(len(class_names)):
  print(class_names[i],' - ',len(list(data_dir_train.glob(class_names[i]+'/*.jpg'))))
# Out:
# actinic keratosis  -  114
# basal cell carcinoma  -  376
# dermatofibroma  -  95
# melanoma  -  438
# nevus  -  357
# pigmented benign keratosis  -  462
# seborrheic keratosis  -  77
# squamous cell carcinoma  -  181
# vascular lesion  -  139

# %% [markdown]
# #### **Todo:** Write your findings here:
# #### - Which class has the least number of samples?
#       Seborrheic keratosis
# #### - Which classes dominate the data in terms proportionate number of samples?
#       Pigmented benign keratosis

# %% [markdown]
# #### **Todo:** Rectify the class imbalance
# #### **Context:** You can use a python package known as `Augmentor` (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %%
# !pip install Augmentor
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting Augmentor
#   Downloading Augmentor-0.2.12-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (8.4.0)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (4.65.0)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (1.22.4)
# Installing collected packages: Augmentor
# Successfully installed Augmentor-0.2.12

# %% [markdown]
# To use `Augmentor`, the following general procedure is followed:
#
# 1. Instantiate a `Pipeline` object pointing to a directory containing your initial image data set.<br>
# 2. Define a number of operations to perform on this data set using your `Pipeline` object.<br>
# 3. Execute these operations by calling the `Pipeline’s` `sample()` method.

# %%
#path_to_training_dataset="/content/gdrive/MyDrive/CNN_Assignment/Skin/Train"
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline("/content/gdrive/MyDrive/CNN_Assignment/Skin/Train",save_format='jpg')
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.
# Out:
# Initialised with 2239 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN_Assignment/Skin/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FD4E423A380>: 100%|██████████| 500/500 [00:47<00:00, 10.62 Samples/s]
# Initialised with 2239 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN_Assignment/Skin/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FD4E42791E0>: 100%|██████████| 500/500 [00:57<00:00,  8.73 Samples/s]
# Initialised with 2239 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN_Assignment/Skin/Train/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x768 at 0x7FD448A58400>: 100%|██████████| 500/500 [00:47<00:00, 10.49 Samples/s]
# Initialised with 2239 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN_Assignment/Skin/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FD4487D3E20>: 100%|██████████| 500/500 [00:57<00:00,  8.75 Samples/s]
# Initialised with 2239 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN_Assignment/Skin/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FD4E40B1BA0>: 100%|██████████| 500/500 [00:56<00:00,  8.82 Samples/s]
# Initialised with 2239 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN_Assignment/Skin/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FD4E701F970>: 100%|██████████| 500/500 [00:48<00:00, 10.40 Samples/s]
# Initialised with 2239 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN_Assignment/Skin/Train/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7FD4486F6110>: 100%|██████████| 500/500 [00:54<00:00,  9.23 Samples/s]
# Initialised with 2239 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN_Assignment/Skin/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FD448A0B820>: 100%|██████████| 500/500 [00:58<00:00,  8.50 Samples/s]
# Initialised with 2239 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN_Assignment/Skin/Train/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FD4E4278460>: 100%|██████████| 500/500 [00:55<00:00,  8.97 Samples/s]

# %% [markdown]
# Augmentor has stored the augmented images in the output sub-directory of each of the sub-directories of skin cancer types.. Lets take a look at total count of augmented images.

# %%
data_dir_train_output = pathlib.Path("/content/gdrive/MyDrive/CNN_Assignment/Skin/Train/output/")
image_count_train = len(list(data_dir_train_output.glob('*/*.jpg')))
print(image_count_train)
# Out:
# 4500

# %% [markdown]
# ### Lets see the distribution of augmented data after adding new images to the original training data.

# %%
from glob import glob
path_list = [x for x in glob(os.path.join(data_dir_train_output, '*', '.jpg'))]
lesion_list_new = [os.path.basename(os.path.dirname(y)) for y in glob(os.path.join(data_dir_train_output, '*', '.jpg'))]

# %%
#dataframe_dict_new = dict(zip(path_list_new, lesion_list_new))
dict_new = dict(zip(path_list, lesion_list_new))
df = pd.DataFrame(list(dict_new.items()),columns = ['Path','Label'])

# %%
df['Label'].value_counts()
# Out:
# Series([], Name: Label, dtype: int64)

# %% [markdown]
# So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %% [markdown]
# #### **Todo**: Train the model on the data created using Augmentor

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# #### **Todo:** Create a training dataset

# %%
#data_dir_train="path to directory with training data + data created using augmentor"
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train_output,
  seed=123,
  validation_split = 0.2,
  subset = "training", ## Todo choose the correct parameter value, so that only training data is refered to,,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 4500 files belonging to 9 classes.
# Using 3600 files for training.

# %% [markdown]
# #### **Todo:** Create a validation dataset

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train_output,
  seed=123,
  validation_split = 0.2,
  subset = "validation", ## Todo choose the correct parameter value, so that only validation data is refered to,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 4500 files belonging to 9 classes.
# Using 900 files for validation.

# %% [markdown]
# #### **Todo:** Create your model (make sure to include normalization)

# %%
## your code goes here

model = Sequential([ data_aug,
                    layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width,3))
      
])
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu', input_shape = (180, 180, 32)))
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.25))
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.25))
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.25))


model.add(Flatten())
model.add(Dense(num_classes, activation = "softmax"))

# %% [markdown]
# #### **Todo:** Compile your model (Choose optimizer and loss function appropriately)

# %%
## your code goes here
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_1 (Sequential)   (None, 180, 180, 3)       0
#
#  rescaling_2 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_9 (Conv2D)           (None, 180, 180, 32)      2432
#
#  conv2d_10 (Conv2D)          (None, 180, 180, 32)      25632
#
#  max_pooling2d_7 (MaxPooling  (None, 90, 90, 32)       0
#  2D)
#
#  dropout_4 (Dropout)         (None, 90, 90, 32)        0
#
#  conv2d_11 (Conv2D)          (None, 90, 90, 32)        25632
#
#  max_pooling2d_8 (MaxPooling  (None, 45, 45, 32)       0
#  2D)
#
#  dropout_5 (Dropout)         (None, 45, 45, 32)        0
#
#  conv2d_12 (Conv2D)          (None, 45, 45, 32)        25632
#
#  max_pooling2d_9 (MaxPooling  (None, 22, 22, 32)       0
#  2D)
#
#  dropout_6 (Dropout)         (None, 22, 22, 32)        0
#
#  flatten_2 (Flatten)         (None, 15488)             0
#
#  dense_2 (Dense)             (None, 9)                 139401
#
# =================================================================
# Total params: 218,729
# Trainable params: 218,729
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### **Todo:**  Train your model

# %%
epochs = 50
## Your code goes here, use 50 epochs.
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/50
# 113/113 [==============================] - 27s 212ms/step - loss: 2.0515 - accuracy: 0.1900 - val_loss: 2.0660 - val_accuracy: 0.2000
# Epoch 2/50
# 113/113 [==============================] - 21s 181ms/step - loss: 1.9681 - accuracy: 0.2417 - val_loss: 1.8469 - val_accuracy: 0.3044
# Epoch 3/50
# 113/113 [==============================] - 23s 194ms/step - loss: 1.7171 - accuracy: 0.3725 - val_loss: 1.5858 - val_accuracy: 0.4467
# Epoch 4/50
# 113/113 [==============================] - 23s 193ms/step - loss: 1.5557 - accuracy: 0.4425 - val_loss: 1.4551 - val_accuracy: 0.4933
# Epoch 5/50
# 113/113 [==============================] - 23s 188ms/step - loss: 1.5326 - accuracy: 0.4611 - val_loss: 1.4972 - val_accuracy: 0.4867
# Epoch 6/50
# 113/113 [==============================] - 22s 182ms/step - loss: 1.4380 - accuracy: 0.4883 - val_loss: 1.3998 - val_accuracy: 0.4944
# Epoch 7/50
# 113/113 [==============================] - 23s 197ms/step - loss: 1.4812 - accuracy: 0.4819 - val_loss: 1.3879 - val_accuracy: 0.5256
# Epoch 8/50
# 113/113 [==============================] - 21s 180ms/step - loss: 1.4069 - accuracy: 0.5094 - val_loss: 1.4036 - val_accuracy: 0.4922
# Epoch 9/50
# 113/113 [==============================] - 22s 191ms/step - loss: 1.3785 - accuracy: 0.5144 - val_loss: 1.3589 - val_accuracy: 0.5056
# Epoch 10/50
# 113/113 [==============================] - 22s 185ms/step - loss: 1.3533 - accuracy: 0.5125 - val_loss: 1.3375 - val_accuracy: 0.5133
# Epoch 11/50
# 113/113 [==============================] - 23s 195ms/step - loss: 1.3545 - accuracy: 0.5081 - val_loss: 1.3320 - val_accuracy: 0.5256
# Epoch 12/50
# 113/113 [==============================] - 22s 183ms/step - loss: 1.2834 - accuracy: 0.5283 - val_loss: 1.2964 - val_accuracy: 0.5189
# Epoch 13/50
# 113/113 [==============================] - 23s 194ms/step - loss: 1.2908 - accuracy: 0.5367 - val_loss: 1.3174 - val_accuracy: 0.5344
# Epoch 14/50
# 113/113 [==============================] - 21s 182ms/step - loss: 1.2492 - accuracy: 0.5433 - val_loss: 1.2865 - val_accuracy: 0.5367
# Epoch 15/50
# 113/113 [==============================] - 23s 192ms/step - loss: 1.2416 - accuracy: 0.5531 - val_loss: 1.3319 - val_accuracy: 0.5033
# Epoch 16/50
# 113/113 [==============================] - 23s 197ms/step - loss: 1.2303 - accuracy: 0.5483 - val_loss: 1.4067 - val_accuracy: 0.4733
# Epoch 17/50
# 113/113 [==============================] - 23s 194ms/step - loss: 1.1885 - accuracy: 0.5728 - val_loss: 1.2973 - val_accuracy: 0.5244
# Epoch 18/50
# 113/113 [==============================] - 23s 195ms/step - loss: 1.2318 - accuracy: 0.5536 - val_loss: 1.2778 - val_accuracy: 0.5367
# Epoch 19/50
# 113/113 [==============================] - 22s 184ms/step - loss: 1.1592 - accuracy: 0.5831 - val_loss: 1.2410 - val_accuracy: 0.5289
# Epoch 20/50
# 113/113 [==============================] - 23s 195ms/step - loss: 1.1638 - accuracy: 0.5803 - val_loss: 1.2065 - val_accuracy: 0.5611
# Epoch 21/50
# 113/113 [==============================] - 23s 189ms/step - loss: 1.1493 - accuracy: 0.5847 - val_loss: 1.4050 - val_accuracy: 0.4711
# Epoch 22/50
# 113/113 [==============================] - 23s 198ms/step - loss: 1.1730 - accuracy: 0.5761 - val_loss: 1.2607 - val_accuracy: 0.5144
# Epoch 23/50
# 113/113 [==============================] - 22s 191ms/step - loss: 1.1209 - accuracy: 0.5969 - val_loss: 1.2108 - val_accuracy: 0.5667
# Epoch 24/50
# 113/113 [==============================] - 23s 195ms/step - loss: 1.1505 - accuracy: 0.5850 - val_loss: 1.2313 - val_accuracy: 0.5467
# Epoch 25/50
# 113/113 [==============================] - 23s 199ms/step - loss: 1.1400 - accuracy: 0.5900 - val_loss: 1.2724 - val_accuracy: 0.5500
# Epoch 26/50
# 113/113 [==============================] - 23s 194ms/step - loss: 1.1580 - accuracy: 0.5744 - val_loss: 1.2084 - val_accuracy: 0.5589
# Epoch 27/50
# 113/113 [==============================] - 21s 183ms/step - loss: 1.0864 - accuracy: 0.6072 - val_loss: 1.1949 - val_accuracy: 0.5711
# Epoch 28/50
# 113/113 [==============================] - 23s 195ms/step - loss: 1.1368 - accuracy: 0.5872 - val_loss: 1.1440 - val_accuracy: 0.5822
# Epoch 29/50
# 113/113 [==============================] - 21s 182ms/step - loss: 1.0871 - accuracy: 0.5983 - val_loss: 1.1376 - val_accuracy: 0.5911
# Epoch 30/50
# 113/113 [==============================] - 23s 190ms/step - loss: 1.0544 - accuracy: 0.6192 - val_loss: 1.1232 - val_accuracy: 0.5900
# Epoch 31/50
# 113/113 [==============================] - 24s 202ms/step - loss: 1.0499 - accuracy: 0.6153 - val_loss: 1.1938 - val_accuracy: 0.5678
# Epoch 32/50
# 113/113 [==============================] - 23s 195ms/step - loss: 1.0671 - accuracy: 0.6150 - val_loss: 1.1894 - val_accuracy: 0.5478
# Epoch 33/50
# 113/113 [==============================] - 21s 182ms/step - loss: 1.0269 - accuracy: 0.6258 - val_loss: 1.0981 - val_accuracy: 0.5778
# Epoch 34/50
# 113/113 [==============================] - 23s 193ms/step - loss: 1.0722 - accuracy: 0.6089 - val_loss: 1.1544 - val_accuracy: 0.5733
# Epoch 35/50
# 113/113 [==============================] - 23s 197ms/step - loss: 1.0141 - accuracy: 0.6281 - val_loss: 1.2206 - val_accuracy: 0.5678
# Epoch 36/50
# 113/113 [==============================] - 22s 182ms/step - loss: 1.0227 - accuracy: 0.6225 - val_loss: 1.0709 - val_accuracy: 0.6033
# Epoch 37/50
# 113/113 [==============================] - 23s 192ms/step - loss: 1.0138 - accuracy: 0.6292 - val_loss: 1.0716 - val_accuracy: 0.5922
# Epoch 38/50
# 113/113 [==============================] - 21s 181ms/step - loss: 0.9966 - accuracy: 0.6344 - val_loss: 1.1630 - val_accuracy: 0.5700
# Epoch 39/50
# 113/113 [==============================] - 24s 207ms/step - loss: 1.0233 - accuracy: 0.6192 - val_loss: 1.1874 - val_accuracy: 0.5522
# Epoch 40/50
# 113/113 [==============================] - 23s 194ms/step - loss: 0.9776 - accuracy: 0.6453 - val_loss: 1.1243 - val_accuracy: 0.6011
# Epoch 41/50
# 113/113 [==============================] - 23s 194ms/step - loss: 0.9839 - accuracy: 0.6356 - val_loss: 1.1610 - val_accuracy: 0.5722
# Epoch 42/50
# 113/113 [==============================] - 21s 182ms/step - loss: 0.9902 - accuracy: 0.6356 - val_loss: 1.1399 - val_accuracy: 0.6011
# Epoch 43/50
# 113/113 [==============================] - 23s 192ms/step - loss: 1.0082 - accuracy: 0.6294 - val_loss: 1.2496 - val_accuracy: 0.5378
# Epoch 44/50
# 113/113 [==============================] - 23s 194ms/step - loss: 0.9511 - accuracy: 0.6472 - val_loss: 1.1901 - val_accuracy: 0.5678
# Epoch 45/50
# 113/113 [==============================] - 23s 197ms/step - loss: 0.9396 - accuracy: 0.6558 - val_loss: 1.1658 - val_accuracy: 0.5900
# Epoch 46/50
# 113/113 [==============================] - 23s 195ms/step - loss: 1.0225 - accuracy: 0.6322 - val_loss: 1.1033 - val_accuracy: 0.6122
# Epoch 47/50
# 113/113 [==============================] - 23s 198ms/step - loss: 0.9306 - accuracy: 0.6558 - val_loss: 1.0889 - val_accuracy: 0.6056
# Epoch 48/50
# 113/113 [==============================] - 23s 198ms/step - loss: 0.9542 - accuracy: 0.6533 - val_loss: 1.1261 - val_accuracy: 0.6044
# Epoch 49/50
# 113/113 [==============================] - 22s 183ms/step - loss: 0.9207 - accuracy: 0.6661 - val_loss: 1.0599 - val_accuracy: 0.6133
# Epoch 50/50
# 113/113 [==============================] - 23s 195ms/step - loss: 0.9303 - accuracy: 0.6658 - val_loss: 1.1032 - val_accuracy: 0.6122

# %% [markdown]
# #### **Todo:**  Visualize the model results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### **Todo:**  Analyze your results here. Did you get rid of underfitting/overfitting? Did class rebalance help?

# %% [markdown]
# 1. As training accuracy increases linearly overtime, where as validation accuracy increases in the process of training.
# 2. Training loss decreases with epochs the validation loss also decreases.
# 3. Above plot shows gap between accuracy for training and validation have decreases significantly compared to previous model and achived around 62% on validation set
# 4. Accuracy difference between training and validation is less
#
# **Rebalancing the classes not only eliminated overfitting but also resulted in an accuracy improvement from 55% to 65%**
